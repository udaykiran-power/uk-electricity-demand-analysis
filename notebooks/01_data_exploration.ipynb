# %%
import pandas as pd
import matplotlib.pyplot as mt
import seaborn as sb
import matplotlib.dates as mdates

# %%
print('Environment ready!')
# Out:
# Environment ready!

# %%
df = pd.read_csv('../data/demand_2026.csv', parse_dates=['SETTLEMENT_DATE'])

# %%
df.head(50)
# Out:
#    SETTLEMENT_DATE  SETTLEMENT_PERIOD     ND FORECAST_ACTUAL_INDICATOR    TSD  \
# 0       2026-01-01                  1  25107                         A  29668
# 1       2026-01-01                  2  25881                         A  30361
# 2       2026-01-01                  3  25355                         A  30681
# 3       2026-01-01                  4  24762                         A  30225
# 4       2026-01-01                  5  24111                         A  29092
# 5       2026-01-01                  6  23637                         A  28521
# 6       2026-01-01                  7  22745                         A  27909
# 7       2026-01-01                  8  22061                         A  27224
# 8       2026-01-01                  9  21715                         A  27508
# 9       2026-01-01                 10  21429                         A  27288
# 10      2026-01-01                 11  21099                         A  27198
# 11      2026-01-01                 12  21047                         A  27136
# 12      2026-01-01                 13  21525                         A  27110
# 13      2026-01-01                 14  21786                         A  27310
# 14      2026-01-01                 15  22674                         A  27214
# 15      2026-01-01                 16  22862                         A  27553
# 16      2026-01-01                 17  24036                         A  27423
# 17      2026-01-01                 18  24747                         A  28009
# 18      2026-01-01                 19  25425                         A  28493
# 19      2026-01-01                 20  25987                         A  29028
# 20      2026-01-01                 21  26752                         A  29799
# 21      2026-01-01                 22  26959                         A  29994
# 22      2026-01-01                 23  27178                         A  30214
# 23      2026-01-01                 24  27697                         A  30767
# 24      2026-01-01                 25  28878                         A  31595
# 25      2026-01-01                 26  29308                         A  32123
# 26      2026-01-01                 27  29551                         A  32281
# 27      2026-01-01                 28  29977                         A  32498
# 28      2026-01-01                 29  30357                         A  32488
# 29      2026-01-01                 30  30466                         A  32586
# 30      2026-01-01                 31  31184                         A  33295
# 31      2026-01-01                 32  32188                         A  34292
# 32      2026-01-01                 33  33178                         A  35279
# 33      2026-01-01                 34  34312                         A  36409
# 34      2026-01-01                 35  35082                         A  37181
# 35      2026-01-01                 36  34820                         A  36920
# 36      2026-01-01                 37  34342                         A  36442
# 37      2026-01-01                 38  33772                         A  35873
# 38      2026-01-01                 39  33088                         A  35200
# 39      2026-01-01                 40  32298                         A  34402
# 40      2026-01-01                 41  31002                         A  33107
# 41      2026-01-01                 42  30312                         A  32419
# 42      2026-01-01                 43  29074                         A  31181
# 43      2026-01-01                 44  28250                         A  30351
# 44      2026-01-01                 45  26740                         A  28849
# 45      2026-01-01                 46  25441                         A  27804
# 46      2026-01-01                 47  24509                         A  27429
# 47      2026-01-01                 48  23967                         A  27298
# 48      2026-01-02                  1  24638                         A  27929
# 49      2026-01-02                  2  25279                         A  28783
#
#     ENGLAND_WALES_DEMAND  EMBEDDED_WIND_GENERATION  EMBEDDED_WIND_CAPACITY  \
# 0                  23625                      4146                    6417
# 1                  24341                      4188                    6417
# 2                  23805                      4085                    6417
# 3                  23226                      4092                    6417
# 4                  22653                      4044                    6417
# 5                  22147                      4149                    6417
# 6                  21334                      4142                    6417
# 7                  20657                      4093                    6417
# 8                  20229                      4100                    6417
# 9                  19981                      4219                    6417
# 10                 19657                      4192                    6417
# 11                 19640                      4210                    6417
# 12                 20093                      4224                    6417
# 13                 20377                      4199                    6417
# 14                 21229                      4064                    6417
# 15                 21399                      3997                    6417
# 16                 22496                      3864                    6417
# 17                 23154                      3873                    6417
# 18                 23709                      3748                    6417
# 19                 24198                      3760                    6417
# 20                 24864                      3725                    6417
# 21                 25003                      3770                    6417
# 22                 25172                      3775                    6417
# 23                 25570                      3926                    6417
# 24                 26716                      3934                    6417
# 25                 27142                      4044                    6417
# 26                 27378                      3976                    6417
# 27                 27726                      4073                    6417
# 28                 28131                      4034                    6417
# 29                 28309                      4049                    6417
# 30                 28959                      4004                    6417
# 31                 29797                      4070                    6417
# 32                 30580                      4014                    6417
# 33                 31643                      4016                    6417
# 34                 32333                      4014                    6417
# 35                 32231                      4033                    6417
# 36                 31848                      3927                    6417
# 37                 31268                      3925                    6417
# 38                 30593                      3866                    6417
# 39                 29801                      3838                    6417
# 40                 28581                      3703                    6417
# 41                 27842                      3711                    6417
# 42                 26677                      3610                    6417
# 43                 25900                      3591                    6417
# 44                 24560                      3439                    6417
# 45                 23426                      3457                    6417
# 46                 22504                      3482                    6417
# 47                 22031                      3617                    6417
# 48                 22657                      3595                    6417
# 49                 23364                      3647                    6417
#
#     EMBEDDED_SOLAR_GENERATION  EMBEDDED_SOLAR_CAPACITY  ...  IFA_FLOW  \
# 0                           0                    22267  ...     -1143
# 1                           0                    22267  ...     -1132
# 2                           0                    22267  ...     -1433
# 3                           0                    22267  ...     -1469
# 4                           0                    22267  ...     -1236
# 5                           0                    22267  ...     -1208
# 6                           0                    22267  ...     -1030
# 7                           0                    22267  ...     -1007
# 8                           0                    22267  ...     -1174
# 9                           0                    22267  ...     -1195
# 10                          0                    22267  ...     -1032
# 11                          0                    22267  ...     -1011
# 12                          0                    22267  ...     -1047
# 13                          0                    22267  ...     -1050
# 14                          0                    22267  ...      -484
# 15                          0                    22267  ...      -415
# 16                          2                    22267  ...      -125
# 17                        234                    22267  ...       -85
# 18                        933                    22267  ...       597
# 19                       1749                    22267  ...       706
# 20                       2380                    22267  ...       970
# 21                       2995                    22267  ...      1002
# 22                       3342                    22267  ...      1003
# 23                       3389                    22267  ...      1003
# 24                       3183                    22267  ...      1416
# 25                       2712                    22267  ...      1466
# 26                       2338                    22267  ...      1496
# 27                       1893                    22267  ...      1499
# 28                       1435                    22267  ...      1482
# 29                       1032                    22267  ...      1480
# 30                        531                    22267  ...      1502
# 31                        108                    22267  ...      1504
# 32                          0                    22267  ...      1504
# 33                          0                    22267  ...      1504
# 34                          0                    22267  ...      1504
# 35                          0                    22267  ...      1504
# 36                          0                    22267  ...      1504
# 37                          0                    22267  ...      1504
# 38                          0                    22267  ...      1427
# 39                          0                    22267  ...      1417
# 40                          0                    22267  ...      1272
# 41                          0                    22267  ...      1253
# 42                          0                    22267  ...       853
# 43                          0                    22267  ...       803
# 44                          0                    22267  ...       641
# 45                          0                    22267  ...       620
# 46                          0                    22267  ...       823
# 47                          0                    22268  ...       851
# 48                          0                    22268  ...      1379
# 49                          0                    22268  ...      1445
#
#     IFA2_FLOW  BRITNED_FLOW  MOYLE_FLOW  EAST_WEST_FLOW  NEMO_FLOW  NSL_FLOW  \
# 0        -610           989        -361            -527        209       677
# 1        -606          1005        -361            -453        243       648
# 2        -594           844        -361            -524        343       667
# 3        -589           837        -361            -531        346       650
# 4        -431           949        -361            -531        146       413
# 5        -423           953        -361            -531        139       359
# 6        -530           726        -361            -531         82        56
# 7        -540           716        -361            -531         80         7
# 8        -617           655        -361            -531        167      -126
# 9        -624           652        -361            -531        164      -143
# 10       -687           738        -361            -531       -387      -148
# 11       -683           741        -361            -531       -412      -162
# 12       -397           786        -361            -531        -45      -337
# 13       -378           787        -361            -531        -20      -350
# 14       -406           799        -421            -531        641      -241
# 15       -397           799        -452            -531        676      -221
# 16        -30           665        -452            -531        833      -150
# 17          1           660        -452            -531        838      -133
# 18        210           599        -452            -531        726       -19
# 19        232           596        -452            -531        722        -5
# 20        532           405        -452            -531        739        -4
# 21        556           384        -452            -531        741       -12
# 22        687             3        -452            -531       1005      -107
# 23        703             1        -452            -531       1014      -105
# 24        970           306        -452            -531       1016        65
# 25        988           342        -452            -531       1016        84
# 26        982           834        -452            -531       1016        54
# 27        983           852        -452            -531       1016        79
# 28        992           317        -452            -531        981       451
# 29        992           298        -452            -531        980       527
# 30        992           920        -452            -531        996       901
# 31        992           953        -452            -531        997       977
# 32        992           701        -452            -531        986      1350
# 33        992           692        -452            -531        985      1397
# 34        992          1009        -452            -531        996      1397
# 35        992          1021        -452            -531        997      1397
# 36        992          1051        -452            -531        997      1397
# 37        991          1052        -452            -531        997      1397
# 38        960          1051        -452            -531        988      1397
# 39        951          1051        -452            -531        988      1397
# 40        722          1048        -452            -531        996      1397
# 41        699          1048        -452            -531        996      1378
# 42        462           807        -452            -531        687      1141
# 43        444           797        -452            -531        668      1083
# 44        397           730        -452            -531        102       710
# 45        390           729        -452            -531         74       635
# 46        271           793        -452            -531        214       262
# 47        276           795        -452            -531        219       186
# 48        709           790        -429            -531        182      -192
# 49        737           789        -361            -531        180      -268
#
#     ELECLINK_FLOW  VIKING_FLOW  GREENLINK_FLOW
# 0            -352         1021            -513
# 1            -359          994            -514
# 2            -754          994            -514
# 3            -770          990            -514
# 4            -475          990            -513
# 5            -460          990            -514
# 6            -596          990            -514
# 7            -613          990            -514
# 8            -887          970            -514
# 9            -903          968            -514
# 10           -855          985            -514
# 11           -849          986            -514
# 12           -786          976            -514
# 13           -780          975            -513
# 14           -658          985            -513
# 15           -633          986            -514
# 16            -35          986            -513
# 17             14          986            -514
# 18            132          989            -514
# 19            148          990            -513
# 20            489          990            -513
# 21            510          990            -513
# 22            515          991            -514
# 23            525          994            -513
# 24            863          992            -514
# 25            883          991            -514
# 26            806          991            -513
# 27            802          992            -514
# 28            834          992            -514
# 29            836          991            -514
# 30            803          991            -514
# 31            806          991            -513
# 32            986          991            -513
# 33            998          990            -513
# 34            997          991            -513
# 35            998          991            -514
# 36            998          991            -514
# 37            996          991            -514
# 38            916          991            -525
# 39            907          991            -514
# 40            777          991            -514
# 41            762          991            -513
# 42            518          991            -514
# 43            498          991            -514
# 44            345          991            -514
# 45            334          991            -514
# 46            291          991            -514
# 47            298          986            -513
# 48            665          814            -514
# 49            688          800            -514
#
# [50 rows x 23 columns]

# %%
print(df.shape)
print(df.columns)
df.info()
df.isnull().sum()
df.describe()
# Out:
# (9214, 23)
# Index(['SETTLEMENT_DATE', 'SETTLEMENT_PERIOD', 'ND',
#        'FORECAST_ACTUAL_INDICATOR', 'TSD', 'ENGLAND_WALES_DEMAND',
#        'EMBEDDED_WIND_GENERATION', 'EMBEDDED_WIND_CAPACITY',
#        'EMBEDDED_SOLAR_GENERATION', 'EMBEDDED_SOLAR_CAPACITY', 'NON_BM_STOR',
#        'PUMP_STORAGE_PUMPING', 'SCOTTISH_TRANSFER', 'IFA_FLOW', 'IFA2_FLOW',
#        'BRITNED_FLOW', 'MOYLE_FLOW', 'EAST_WEST_FLOW', 'NEMO_FLOW', 'NSL_FLOW',
#        'ELECLINK_FLOW', 'VIKING_FLOW', 'GREENLINK_FLOW'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9214 entries, 0 to 9213
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   SETTLEMENT_DATE            9214 non-null   datetime64[ns]
#  1   SETTLEMENT_PERIOD          9214 non-null   int64
#  2   ND                         9214 non-null   int64
#  3   FORECAST_ACTUAL_INDICATOR  9214 non-null   object
#  4   TSD                        9214 non-null   int64
#  5   ENGLAND_WALES_DEMAND       9214 non-null   int64
#  6   EMBEDDED_WIND_GENERATION   9214 non-null   int64
#  7   EMBEDDED_WIND_CAPACITY     9214 non-null   int64
#  8   EMBEDDED_SOLAR_GENERATION  9214 non-null   int64
#  9   EMBEDDED_SOLAR_CAPACITY    9214 non-null   int64
#  10  NON_BM_STOR                9214 non-null   int64
#  11  PUMP_STORAGE_PUMPING       9214 non-null   int64
#  12  SCOTTISH_TRANSFER          9214 non-null   int64
#  13  IFA_FLOW                   9214 non-null   int64
#  14  IFA2_FLOW                  9214 non-null   int64
#  15  BRITNED_FLOW               9214 non-null   int64
#  16  MOYLE_FLOW                 9214 non-null   int64
#  17  EAST_WEST_FLOW             9214 non-null   int64
#  18  NEMO_FLOW                  9214 non-null   int64
#  19  NSL_FLOW                   9214 non-null   int64
#  20  ELECLINK_FLOW              9214 non-null   int64
#  21  VIKING_FLOW                9214 non-null   int64
#  22  GREENLINK_FLOW             9214 non-null   int64
# dtypes: datetime64[ns](1), int64(21), object(1)
# memory usage: 1.6+ MB
#                      SETTLEMENT_DATE  SETTLEMENT_PERIOD            ND  \
# count                           9214        9214.000000   9214.000000
# mean   2026-04-06 12:02:39.409593856          24.495008  26386.846646
# min              2026-01-01 00:00:00           1.000000  12626.000000
# 25%              2026-02-17 06:00:00          12.250000  21890.000000
# 50%              2026-04-07 00:00:00          24.000000  25230.000000
# 75%              2026-05-24 18:00:00          36.000000  29824.500000
# max              2026-07-11 00:00:00          48.000000  47382.000000
# std                              NaN          13.851507   6237.393416
#
#                 TSD  ENGLAND_WALES_DEMAND  EMBEDDED_WIND_GENERATION  \
# count   9214.000000           9214.000000               9214.000000
# mean   28944.570653          24227.430649               2008.467658
# min    13803.000000          11159.000000                190.000000
# 25%    24343.000000          20083.500000                937.000000
# 50%    27823.500000          23191.000000               1672.500000
# 75%    32422.500000          27435.000000               2876.500000
# max    50101.000000          42669.000000               5761.000000
# std     6422.177604           5748.221588               1290.826235
#
#        EMBEDDED_WIND_CAPACITY  EMBEDDED_SOLAR_GENERATION  \
# count                  9214.0                9214.000000
# mean                   6417.0                2618.053940
# min                    6417.0                   0.000000
# 25%                    6417.0                   0.000000
# 50%                    6417.0                 108.000000
# 75%                    6417.0                4318.500000
# max                    6417.0               16289.000000
# std                       0.0                3901.247755
#
#        EMBEDDED_SOLAR_CAPACITY  NON_BM_STOR  ...     IFA_FLOW    IFA2_FLOW  \
# count              9214.000000       9214.0  ...  9214.000000  9214.000000
# mean              22951.234209          0.0  ...  1203.332320   755.417300
# min               22267.000000          0.0  ... -1521.000000 -1027.000000
# 25%               22521.000000          0.0  ...  1002.000000   655.000000
# 50%               23231.000000          0.0  ...  1496.000000   991.000000
# 75%               23301.000000          0.0  ...  1505.000000   992.000000
# max               23301.000000          0.0  ...  2012.000000   994.000000
# std                 394.950257          0.0  ...   519.745075   387.643432
#
#        BRITNED_FLOW   MOYLE_FLOW  EAST_WEST_FLOW    NEMO_FLOW     NSL_FLOW  \
# count   9214.000000  9214.000000     9214.000000  9214.000000  9214.000000
# mean     170.126872  -252.967332     -193.910788   273.024202   474.654873
# min    -1095.000000  -453.000000     -532.000000 -1043.000000 -1453.000000
# 25%     -547.000000  -451.000000     -507.000000  -267.000000  -253.000000
# 50%      303.000000  -351.000000      -16.000000   458.000000   877.500000
# 75%      949.000000    -4.000000        0.000000   951.750000  1397.000000
# max     1079.000000   295.000000      265.000000  1017.000000  1443.000000
# std      759.212366   217.473987      239.525952   690.296001  1015.703196
#
#        ELECLINK_FLOW  VIKING_FLOW  GREENLINK_FLOW
# count    9214.000000  9214.000000     9214.000000
# mean      840.783699   236.864337     -301.039722
# min      -951.000000 -1454.000000     -538.000000
# 25%       830.000000  -538.000000     -514.000000
# 50%       996.000000   268.000000     -477.000000
# 75%       997.000000   991.000000        0.000000
# max      1000.000000  1431.000000      300.000000
# std       302.236731   908.829632      257.835603
#
# [8 rows x 22 columns]

# %%
print(df['SETTLEMENT_DATE'].min())
print(df['SETTLEMENT_DATE'].max())
# Out:
# 2026-01-01 00:00:00
# 2026-07-11 00:00:00

# %%
fig = mt.figure(figsize=(14,5))
ax = fig.add_axes([0,0,1,1])
ax.set_title('UK Total System Demand Over Time')
ax.set_xlabel('Date')
ax.set_ylabel('Demand(MW)')
ax.plot(df['SETTLEMENT_DATE'], df['TSD'])

# %%
sb.set_theme(style='darkgrid', context='notebook')
fig, ax = mt.subplots(figsize=(14,5))
ax.set_title('UK Total System Demand Over Time', fontsize=18, fontweight='bold', loc='center', fontfamily='Times New Roman', pad=10)
ax.set_xlabel('Date', fontsize=13, labelpad=10)
ax.set_ylabel('Demand(MW)', fontsize=13, labelpad=10)
ax.plot(df['SETTLEMENT_DATE'], df['TSD'], color="#2b1fb4", linewidth=1.5, alpha=1)
ax.tick_params(axis='both', labelsize=12)
mt.tight_layout()

# %%
daily_demand = df.groupby(by=df['SETTLEMENT_DATE'].dt.date)['TSD'].mean().reset_index()
daily_demand.columns = ['Date', 'Avg_demand']
daily_demand.head(10)
# Out:
#          Date    Avg_demand
# 0  2026-01-01  30688.062500
# 1  2026-01-02  33104.479167
# 2  2026-01-03  32898.645833
# 3  2026-01-04  35284.500000
# 4  2026-01-05  41768.625000
# 5  2026-01-06  41064.604167
# 6  2026-01-07  38506.020833
# 7  2026-01-08  39411.625000
# 8  2026-01-09  38509.708333
# 9  2026-01-10  35330.979167

# %%
sb.set_theme(style='whitegrid', context='notebook')
fig, ax = mt.subplots(figsize=(14,5))
ax.set_xlabel('Date', fontsize=13, labelpad=10)
ax.set_ylabel('Average Demand(MW)', fontsize=13, labelpad=10)
ax.set_title('UK Daily Average Electricity Demand', fontsize=16, fontweight='bold', loc='center', fontfamily='Times New Roman', pad=10)
ax.plot(daily_demand['Date'], daily_demand['Avg_demand'], color="#cd2421", linewidth=1.5, alpha=1)
ax.xaxis.set_major_locator(mdates.MonthLocator())
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %Y'))
ax.yaxis.set_major_locator(mt.MaxNLocator(6))
mt.tight_layout()

# %%
daily_demand['Date'] = pd.to_datetime(daily_demand['Date'])
daily_demand['Day_of_week'] = daily_demand['Date'].dt.day_name()
daily_demand['Is_weekend'] = daily_demand['Date'].dt.day_of_week >=5
daily_demand.head()
# Out:
#         Date    Avg_demand Day_of_week  Is_weekend
# 0 2026-01-01  30688.062500    Thursday       False
# 1 2026-01-02  33104.479167      Friday       False
# 2 2026-01-03  32898.645833    Saturday        True
# 3 2026-01-04  35284.500000      Sunday        True
# 4 2026-01-05  41768.625000      Monday       False

# %%
Weekend_comparision = daily_demand.groupby(by=['Is_weekend'])['Avg_demand'].mean()

# %%
fig, ax = mt.subplots(figsize=(6,5))
Weekend_comparision.plot(kind='bar',ax=ax, color=["#eb1212", "#5740db"])
ax.set_xlabel('Is Weekend', fontsize=13, labelpad=0, loc='center')
ax.set_xticklabels(['Weekday', 'Weekend'], rotation=0)
ax.set_title('Weekday vs Weekend Average Demand (MW)', fontsize=16, fontweight='bold', loc='center', fontfamily='Times New Roman', pad=10)
ax.set_ylabel('Average Demand(MW)', fontsize=13, labelpad=7)
ax.yaxis.set_major_locator(mt.MaxNLocator(7))
mt.tight_layout()
mt.show()

# %%
daily_demand['Month'] = daily_demand['Date'].dt.month_name()
monthly_demand = daily_demand.groupby(by='Month', sort=False)['Avg_demand'].mean()
monthly_demand = monthly_demand.reindex(daily_demand['Date'].dt.month_name().unique())
monthly_demand
# Out:
# Month
# January     35494.862231
# February    34545.712054
# March       30151.813961
# April       26266.654167
# May         24614.212366
# June        24662.370833
# July        24010.651515
# Name: Avg_demand, dtype: float64

# %%
monthly_demand_df = monthly_demand.reset_index()
monthly_demand_df.columns = ['Month', 'Avg_demand']

fig, ax = mt.subplots(figsize=(10,5))
ax.bar(x=monthly_demand_df['Month'], height=monthly_demand_df['Avg_demand'], color='#2b1fb4')
ax.set_xlabel('Month', fontsize=13, labelpad=7, loc='center')
ax.set_ylabel('Average Demand(MW)', fontsize=13, labelpad=7, loc='center')
ax.set_title('UK Average Monthly Electricity Demand', fontsize=16, fontweight='bold', loc='center', fontfamily='Times New Roman', pad=10)
ax.tick_params(axis='x', rotation=0)
mt.tight_layout()
mt.show()
#ax.yaxis.set_major_locator(mt.MaxNLocator())

# %%
period_demand = df.groupby(by='SETTLEMENT_PERIOD')['TSD'].mean()
period_demand = period_demand.reset_index()
period_demand.columns = ['Settlement_Period', 'Average_Demand(MW)']
period_demand
# Out:
#     Settlement_Period  Average_Demand(MW)
# 0                   1        26769.166667
# 1                   2        26784.000000
# 2                   3        26567.130208
# 3                   4        26245.932292
# 4                   5        25937.218750
# 5                   6        25498.088542
# 6                   7        25202.593750
# 7                   8        24850.682292
# 8                   9        24782.619792
# 9                  10        24633.880208
# 10                 11        24913.739583
# 11                 12        25271.338542
# 12                 13        26444.625000
# 13                 14        27711.057292
# 14                 15        28901.604167
# 15                 16        29623.098958
# 16                 17        30020.125000
# 17                 18        29979.734375
# 18                 19        29962.822917
# 19                 20        29553.416667
# 20                 21        29150.229167
# 21                 22        28728.265625
# 22                 23        28414.947917
# 23                 24        28153.536458
# 24                 25        28155.135417
# 25                 26        27993.005208
# 26                 27        27906.369792
# 27                 28        27781.692708
# 28                 29        27780.062500
# 29                 30        27919.052083
# 30                 31        28264.052083
# 31                 32        29094.187500
# 32                 33        30116.375000
# 33                 34        31445.781250
# 34                 35        32770.442708
# 35                 36        33771.135417
# 36                 37        34427.442708
# 37                 38        34673.177083
# 38                 39        34876.380208
# 39                 40        34540.427083
# 40                 41        33934.458333
# 41                 42        33222.640625
# 42                 43        32292.687500
# 43                 44        31201.239583
# 44                 45        29968.375000
# 45                 46        28661.479167
# 46                 47        27574.696335
# 47                 48        26851.204188

# %%
sb.set_theme(style='whitegrid', context='notebook')
fig, ax = mt.subplots(figsize=(12,5))
ax.plot(period_demand['Settlement_Period'], period_demand['Average_Demand(MW)'], color="#2d23e9")
peak_period = period_demand['Average_Demand(MW)'].idxmax()
peak_value = period_demand['Average_Demand(MW)'].max()
peak_x = period_demand.loc[peak_period, 'Settlement_Period']
ax.scatter(peak_x, peak_value, color='red', s=50, zorder=5)
ax.annotate(f'Peak:{peak_value:.0f} MW', xy=(peak_x, peak_value), xytext=(peak_x+1, peak_value+50), fontsize=11, color='red', fontfamily='arial')
ax.set_xlabel('Settlement Period (1=00:00, 48=23:30)', fontsize=13, labelpad=7, loc='center')
ax.set_ylabel('Average Demand(MW)', fontsize=13, labelpad=7, loc='center')
ax.set_title('UK Average Demand by Time of Day(Half-Hourly Period)', fontsize=16, fontweight='bold', loc='center', fontfamily='Times New Roman', pad=10)
ax.tick_params(axis='both', rotation=0)
ax.xaxis.set_major_locator(mt.MaxNLocator(10))
mt.tight_layout()

# %%
peak_row = period_demand.loc[period_demand['Average_Demand(MW)'].idxmax()]
print(peak_row)
# Out:
# Settlement_Period        39.000000
# Average_Demand(MW)    34876.380208
# Name: 38, dtype: float64
